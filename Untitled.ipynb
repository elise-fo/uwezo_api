# %%
# write some code for the API here
from pandas.core.indexing import maybe_convert_ix
from fastapi import FastAPI
from fastapi.responses import JSONResponse
from fastapi.middleware.cors import CORSMiddleware
import pandas as pd 
import numpy as np
import json
from urllib.request import urlopen

data = pd.read_excel('uwezo_api/data/mapping.xlsx', engine = 'openpyxl', sheet_name = 'Template')

# %%
data = data.rename(columns=lambda x: x if not 'Unnamed' in str(x) else '')\
    .dropna(axis = 0, how = 'all').dropna(axis = 1, how = 'all')
data
# Out:
#                           name  \
# 0                 Ennovate Hub
# 1     ANDE East Africa Chapter
# 2                   Apps&Girls
# 3  UN Capital Development Fund
# 4                      Darecha
# 5                   Uhuru Labs
# 6                           Xx
#
#                                         locationName  longitude  latitude  \
# 0         15 Regent Street, Dar Es Salaam\n Tanzania  39.247088 -6.756361
# 1                                            Nairobi  39.247089 -6.756362
# 2      Mafeke St, house no 22 Dar es Salaam Tanzania  39.247090  6.756363
# 3  UNCDF, 22, Mahando Street, Sea Cliff, Masaki, ...  29.280000  4.530000
# 4  25, Regent Street, Mikocheni, Dar es Salaam, C...  39.247092 -6.756365
# 5  Uhurulabs Ltd, Manonge Street 6, Regent Estate...  39.247093 -6.756366
# 6                                                 xx  39.247094 -6.756367
#
#     country                        classification womenSpecific  \
# 0  Tanzania       Incubators, Accelerators & Hubs            No
# 1  Tanzania  Professional Associations & Networks            No
# 2  Tanzania                                  NGOs           Yes
# 3  Tanzania                    Development Agency            No
# 4  Tanzania                MFIs, Banks, Investors            No
# 5  Tanzania        Local Consultants & Businesses            No
# 6  Tanzania                    Public Inititiaves            xx
#
#   socialEntrepreneurSpecific yearFounded  \
# 0                        Yes        2018
# 1                         No        2009
# 2                        Yes        2013
# 3                         No        1982
# 4                         No        2008
# 5                         No        2015
# 6                         xx          xx
#
#                                          description  \
# 0  Ennovate Hub is an impact innovation hub with ...
# 1  The Aspen Network of Development Entrepreneurs...
# 2  Aims to bridge the gender gap in ICT in Tanzan...
# 3  The UN Capital Development Fund makes public a...
# 4  Darecha is a Tanzanian micro-venture capital f...
# 5  Uhrub Labs is a company leveraging technology ...
# 6                                                 xx
#
#                      sectors  \
# 0                       Tech
# 1                    No data
# 2                       Tech
# 3  Tech; Finance & Insurance
# 4                    No data
# 5                    No data
# 6                         xx
#
#                                          supportType  \
# 0  Entrepreneurship training/courses; Workshops &...
# 1  Entrepreneurship training/courses; Workshops &...
# 2  Entrepreneurship training/courses; Workshops &...
# 3                                            Funding
# 4                                            Funding
# 5                                 Avocacy/Consulting
# 6                                                 xx
#
#                        fundingType                innovationStages  \
# 0                          No data                 Ideation; Pilot
# 1                          No data                Small businesses
# 2                          No data                         No data
# 3    Debt; Equity; Venture Capital  Ideation; Pilot; Growth; Scale
# 4  Venture Capital/ Angel Investor                Small businesses
# 5                          No data                         No data
# 6                               xx                              xx
#
#                                              website  \
# 0                        https://www.ennovatehub.com
# 1         https://www.andeglobal.org/page/EastAfrica
# 2  https://www.appsandgirls.com/cgi-sys/suspended...
# 3                     https://www.uncdf.org/tanzania
# 4                            http://www.darecha.org/
# 5           http://website.uhurulabs.org/projects-2/
# 6                                                 xx
#
#                                 email                phone  \
# 0                info@ennovatehub.com      255 752 817 723
# 1  Maryanne.Ochola@aspeninstitute.org              No data
# 2               info@appsandgirls.com      255 658 050 383
# 3              peter.malika@uncdf.org              No data
# 4                    info@darecha.org      255 712 358 544
# 5               support@uhurulabs.org  255 (0) 76 5376 131
# 6                                  xx                   xx
#
#                                  facebook      instagram  _id
# 0                                 No data        No data    1
# 1                                 No data        No data    2
# 2  https://www.facebook.com/AppsAndGirls/  @AppsAndGirls    3
# 3                                 No data        No data    4
# 4                                 Darecha     @darechatz    5
# 5                                 No data        No data    6
# 6                                      xx             xx    7

# %%
data
# Out:
#                           name  \
# 1     ANDE East Africa Chapter
# 2                   Apps&Girls
# 3  UN Capital Development Fund
# 4                      Darecha
# 5                   Uhuru Labs
# 6                           Xx
#
#                                         locationName  longitude  latitude  \
# 1                                            Nairobi  39.247089 -6.756362
# 2      Mafeke St, house no 22 Dar es Salaam Tanzania  39.247090  6.756363
# 3  UNCDF, 22, Mahando Street, Sea Cliff, Masaki, ...  29.280000  4.530000
# 4  25, Regent Street, Mikocheni, Dar es Salaam, C...  39.247092 -6.756365
# 5  Uhurulabs Ltd, Manonge Street 6, Regent Estate...  39.247093 -6.756366
# 6                                                 xx  39.247094 -6.756367
#
#     country                      type_stakeholder womenSpecific  \
# 1  Tanzania  Professional Associations & Networks            No
# 2  Tanzania                                  NGOs           Yes
# 3  Tanzania                    Development Agency            No
# 4  Tanzania                MFIs, Banks, Investors            No
# 5  Tanzania        Local Consultants & Businesses            No
# 6  Tanzania                    Public Inititiaves            xx
#
#   socialEntrepreneurSpecific yearFounded  \
# 1                         No        2009
# 2                        Yes        2013
# 3                         No        1982
# 4                         No        2008
# 5                         No        2015
# 6                         xx          xx
#
#                                          description  \
# 1  The Aspen Network of Development Entrepreneurs...
# 2  Aims to bridge the gender gap in ICT in Tanzan...
# 3  The UN Capital Development Fund makes public a...
# 4  Darecha is a Tanzanian micro-venture capital f...
# 5  Uhrub Labs is a company leveraging technology ...
# 6                                                 xx
#
#                      sectors  \
# 1                    No data
# 2                       Tech
# 3  Tech; Finance & Insurance
# 4                    No data
# 5                    No data
# 6                         xx
#
#                                          supportType  \
# 1  Entrepreneurship training/courses; Workshops &...
# 2  Entrepreneurship training/courses; Workshops &...
# 3                                            Funding
# 4                                            Funding
# 5                                 Avocacy/Consulting
# 6                                                 xx
#
#                        fundingType                innovationStages  \
# 1                          No data                Small businesses
# 2                          No data                         No data
# 3    Debt; Equity; Venture Capital  Ideation; Pilot; Growth; Scale
# 4  Venture Capital/ Angel Investor                Small businesses
# 5                          No data                         No data
# 6                               xx                              xx
#
#                                              website  \
# 1         https://www.andeglobal.org/page/EastAfrica
# 2  https://www.appsandgirls.com/cgi-sys/suspended...
# 3                     https://www.uncdf.org/tanzania
# 4                            http://www.darecha.org/
# 5           http://website.uhurulabs.org/projects-2/
# 6                                                 xx
#
#                                 email                phone  \
# 1  Maryanne.Ochola@aspeninstitute.org              No data
# 2               info@appsandgirls.com      255 658 050 383
# 3              peter.malika@uncdf.org              No data
# 4                    info@darecha.org      255 712 358 544
# 5               support@uhurulabs.org  255 (0) 76 5376 131
# 6                                  xx                   xx
#
#                                  facebook      instagram  _id
# 1                                 No data        No data    2
# 2  https://www.facebook.com/AppsAndGirls/  @AppsAndGirls    3
# 3                                 No data        No data    4
# 4                                 Darecha     @darechatz    5
# 5                                 No data        No data    6
# 6                                      xx             xx    7

# %%
def coord(longitude, latitude):
    location = {
        'type':'Point',
        'coordinates':[longitude, latitude]
    }
    return location
data['location'] = pd.Series(map(lambda lon,lat:coord(lon, lat),
                                          data['longitude'],
                                          data['latitude']
                                    ))
def notNone(s):
    if s is None:
        return ''
    else:
        return s

def transform_in_dict(website, email, phone, facebook, instagram):
    contact = [{'name':'website', 'url':notNone(website)}, 
                {'name':'email', 'url':notNone(email)},
                {'name':'phone', 'url':notNone(phone)},
                {'name':'facebook', 'url':notNone(facebook)},
                {'name':'instagram', 'url':notNone(instagram)}
              ]
    return contact

# %%
data['type_stakeholder'] = data['type_stakeholder'].str.replace("&","and")
mapping_classification = {
    'Incubators, Accelerators and Hubs':'IAH',
    'Professional Associations and Networks':'PAN',
    'NGOs':'NGO',
    'Development Agency':'DA',
    'MFIs, Banks, Investors':'MBI',
    'Local Consultants and Businesses':'LCB',
    'Public Inititiaves':'PI'
}
data['classification'] = data['type_stakeholder'].map(mapping_classification)

# %%
data.type_stakeholder
# Out:
# 1    Professional Associations and Networks
# 2                                      NGOs
# 3                        Development Agency
# 4                    MFIs, Banks, Investors
# 5          Local Consultants and Businesses
# 6                        Public Inititiaves
# Name: type_stakeholder, dtype: object

# %%
data.classification
# Out:
# 1    PAN
# 2    NGO
# 3     DA
# 4    MBI
# 5    LCB
# 6     PI
# Name: classification, dtype: object

# %%
data['socialMedias'] = pd.Series(map(lambda a,b,c,d,e:transform_in_dict(a,b,c,d,e),
                                          data['website'],
                                          data['email'],
                                          data['phone'],
                                          data['facebook'],
                                          data['instagram']
                                    ))
data = data.fillna('').astype('object')
data = data[['location','_id','locationName','socialMedias','country','sectors','name','email','website','classification', 'type_stakeholder', 'phone','instagram','facebook', 'womenSpecific', 'socialEntrepreneurSpecific', 'yearFounded', 'description', 'supportType', 'fundingType', 'innovationStages']]

# %%
data.type_stakeholder
# Out:
# 1    Professional Associations and Networks
# 2                                      NGOs
# 3                        Development Agency
# 4                    MFIs, Banks, Investors
# 5          Local Consultants and Businesses
# 6                        Public Inititiaves
# Name: type_stakeholder, dtype: object

# %%
data
# Out:
#                                             location _id  \
# 1  {'type': 'Point', 'coordinates': [39.24709, 6....   2
# 2    {'type': 'Point', 'coordinates': [29.28, 4.53]}   3
# 3  {'type': 'Point', 'coordinates': [39.247092, -...   4
# 4  {'type': 'Point', 'coordinates': [39.247093, -...   5
# 5  {'type': 'Point', 'coordinates': [39.247094, -...   6
# 6                                                      7
#
#                                         locationName  \
# 1                                            Nairobi
# 2      Mafeke St, house no 22 Dar es Salaam Tanzania
# 3  UNCDF, 22, Mahando Street, Sea Cliff, Masaki, ...
# 4  25, Regent Street, Mikocheni, Dar es Salaam, C...
# 5  Uhurulabs Ltd, Manonge Street 6, Regent Estate...
# 6                                                 xx
#
#                                         socialMedias   country  \
# 1  [{'name': 'website', 'url': 'https://www.appsa...  Tanzania
# 2  [{'name': 'website', 'url': 'https://www.uncdf...  Tanzania
# 3  [{'name': 'website', 'url': 'http://www.darech...  Tanzania
# 4  [{'name': 'website', 'url': 'http://website.uh...  Tanzania
# 5  [{'name': 'website', 'url': 'xx'}, {'name': 'e...  Tanzania
# 6                                                     Tanzania
#
#                      sectors                         name  \
# 1                    No data     ANDE East Africa Chapter
# 2                       Tech                   Apps&Girls
# 3  Tech; Finance & Insurance  UN Capital Development Fund
# 4                    No data                      Darecha
# 5                    No data                   Uhuru Labs
# 6                         xx                           Xx
#
#                                 email  \
# 1  Maryanne.Ochola@aspeninstitute.org
# 2               info@appsandgirls.com
# 3              peter.malika@uncdf.org
# 4                    info@darecha.org
# 5               support@uhurulabs.org
# 6                                  xx
#
#                                              website classification  ...  \
# 1         https://www.andeglobal.org/page/EastAfrica            PAN  ...
# 2  https://www.appsandgirls.com/cgi-sys/suspended...            NGO  ...
# 3                     https://www.uncdf.org/tanzania             DA  ...
# 4                            http://www.darecha.org/            MBI  ...
# 5           http://website.uhurulabs.org/projects-2/            LCB  ...
# 6                                                 xx             PI  ...
#
#                  phone      instagram                                facebook  \
# 1              No data        No data                                 No data
# 2      255 658 050 383  @AppsAndGirls  https://www.facebook.com/AppsAndGirls/
# 3              No data        No data                                 No data
# 4      255 712 358 544     @darechatz                                 Darecha
# 5  255 (0) 76 5376 131        No data                                 No data
# 6                   xx             xx                                      xx
#
#   womenSpecific socialEntrepreneurSpecific yearFounded  \
# 1            No                         No        2009
# 2           Yes                        Yes        2013
# 3            No                         No        1982
# 4            No                         No        2008
# 5            No                         No        2015
# 6            xx                         xx          xx
#
#                                          description  \
# 1  The Aspen Network of Development Entrepreneurs...
# 2  Aims to bridge the gender gap in ICT in Tanzan...
# 3  The UN Capital Development Fund makes public a...
# 4  Darecha is a Tanzanian micro-venture capital f...
# 5  Uhrub Labs is a company leveraging technology ...
# 6                                                 xx
#
#                                          supportType  \
# 1  Entrepreneurship training/courses; Workshops &...
# 2  Entrepreneurship training/courses; Workshops &...
# 3                                            Funding
# 4                                            Funding
# 5                                 Avocacy/Consulting
# 6                                                 xx
#
#                        fundingType                innovationStages
# 1                          No data                Small businesses
# 2                          No data                         No data
# 3    Debt; Equity; Venture Capital  Ideation; Pilot; Growth; Scale
# 4  Venture Capital/ Angel Investor                Small businesses
# 5                          No data                         No data
# 6                               xx                              xx
#
# [6 rows x 21 columns]

# %%
stakeholder = 'All'
womenspecific = 'All'
socialentrepreneurship = 'All'



stakeholders = ['IAH',
        'PAN',
        'NGO',
        'DA',
        'MBI',
        'LCB',
        'PI'
]

if stakeholder == 'All':
    stakeholder = stakeholders
else:
    stakeholder = [stakeholder]
if womenspecific == 'All':
    womenspecific = ['Yes','No']
else:
    womenspecific = [womenspecific]
if socialentrepreneurship == 'All':
    socialentrepreneurship = ['Yes','No']
else:
    socialentrepreneurship = [socialentrepreneurship]

df = data[data['classification'].isin(stakeholder) 
 & data['womenSpecific'].isin(womenspecific)
 & data['socialEntrepreneurSpecific'].isin(socialentrepreneurship) 
]
data_dict = {'data':df.to_dict(orient = 'records')}

# %%
data['womenSpecific']
# Out:
# 1     No
# 2    Yes
# 3     No
# 4     No
# 5     No
# 6     xx
# Name: womenSpecific, dtype: object

# %%
data['womenSpecific'].isin(womenspecificenspecific)
# Out:
# 1     True
# 2     True
# 3     True
# 4     True
# 5     True
# 6    False
# Name: womenSpecific, dtype: bool

# %%
data['classification']
# Out:
# 1    PAN
# 2    NGO
# 3     DA
# 4    MBI
# 5    LCB
# 6     PI
# Name: classification, dtype: object

# %%
df
# Out:
#                                             location _id  \
# 1  {'type': 'Point', 'coordinates': [39.24709, 6....   2
# 2    {'type': 'Point', 'coordinates': [29.28, 4.53]}   3
# 3  {'type': 'Point', 'coordinates': [39.247092, -...   4
# 4  {'type': 'Point', 'coordinates': [39.247093, -...   5
# 5  {'type': 'Point', 'coordinates': [39.247094, -...   6
#
#                                         locationName  \
# 1                                            Nairobi
# 2      Mafeke St, house no 22 Dar es Salaam Tanzania
# 3  UNCDF, 22, Mahando Street, Sea Cliff, Masaki, ...
# 4  25, Regent Street, Mikocheni, Dar es Salaam, C...
# 5  Uhurulabs Ltd, Manonge Street 6, Regent Estate...
#
#                                         socialMedias   country  \
# 1  [{'name': 'website', 'url': 'https://www.appsa...  Tanzania
# 2  [{'name': 'website', 'url': 'https://www.uncdf...  Tanzania
# 3  [{'name': 'website', 'url': 'http://www.darech...  Tanzania
# 4  [{'name': 'website', 'url': 'http://website.uh...  Tanzania
# 5  [{'name': 'website', 'url': 'xx'}, {'name': 'e...  Tanzania
#
#                      sectors                         name  \
# 1                    No data     ANDE East Africa Chapter
# 2                       Tech                   Apps&Girls
# 3  Tech; Finance & Insurance  UN Capital Development Fund
# 4                    No data                      Darecha
# 5                    No data                   Uhuru Labs
#
#                                 email  \
# 1  Maryanne.Ochola@aspeninstitute.org
# 2               info@appsandgirls.com
# 3              peter.malika@uncdf.org
# 4                    info@darecha.org
# 5               support@uhurulabs.org
#
#                                              website classification  ...  \
# 1         https://www.andeglobal.org/page/EastAfrica            PAN  ...
# 2  https://www.appsandgirls.com/cgi-sys/suspended...            NGO  ...
# 3                     https://www.uncdf.org/tanzania             DA  ...
# 4                            http://www.darecha.org/            MBI  ...
# 5           http://website.uhurulabs.org/projects-2/            LCB  ...
#
#                  phone      instagram                                facebook  \
# 1              No data        No data                                 No data
# 2      255 658 050 383  @AppsAndGirls  https://www.facebook.com/AppsAndGirls/
# 3              No data        No data                                 No data
# 4      255 712 358 544     @darechatz                                 Darecha
# 5  255 (0) 76 5376 131        No data                                 No data
#
#   womenSpecific socialEntrepreneurSpecific yearFounded  \
# 1            No                         No        2009
# 2           Yes                        Yes        2013
# 3            No                         No        1982
# 4            No                         No        2008
# 5            No                         No        2015
#
#                                          description  \
# 1  The Aspen Network of Development Entrepreneurs...
# 2  Aims to bridge the gender gap in ICT in Tanzan...
# 3  The UN Capital Development Fund makes public a...
# 4  Darecha is a Tanzanian micro-venture capital f...
# 5  Uhrub Labs is a company leveraging technology ...
#
#                                          supportType  \
# 1  Entrepreneurship training/courses; Workshops &...
# 2  Entrepreneurship training/courses; Workshops &...
# 3                                            Funding
# 4                                            Funding
# 5                                 Avocacy/Consulting
#
#                        fundingType                innovationStages
# 1                          No data                Small businesses
# 2                          No data                         No data
# 3    Debt; Equity; Venture Capital  Ideation; Pilot; Growth; Scale
# 4  Venture Capital/ Angel Investor                Small businesses
# 5                          No data                         No data
#
# [5 rows x 21 columns]
